# %% [markdown]
# <a href="https://colab.research.google.com/github/ZyadMedhat054/Pharmacy-Web/blob/main/Intelligent_Database_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data** **Cleaning**

# %%
# import pandas library
import pandas as pd 
# Read Data 
data = pd.read_csv('data.csv',header = 0)
display(data) # to show data

# import pandas library
import pandas as pd 
# Read Data 
weather = pd.read_csv('weather.csv',header = 0)
display(weather) # to show data

# import pandas library
import pandas as pd 
# Read Data 
fuel = pd.read_csv('fuel pricing.csv',header = 0)
display(fuel)
avg = weather.groupby('Store').mean()
display(avg)
data['Date']=pd.to_datetime(data['Date'])
data.dtypes
#display(data.dtypes)
weather['Date']=pd.to_datetime(weather['Date'])
weather.dtypes
#display(weather.dtypes)
fuel['Date']=pd.to_datetime(fuel['Date'])
fuel.dtypes
#display(fuel.dtypes)
#display(data.loc[:9]) 
#display(weather.loc[:9])
#display(fuel.loc[:9])
#data.csv
missing_data = data.isnull().sum()
#negative_sales = data[data['Weekly_Sales'] <= 0]
print("Missing data:\n", missing_data)
#print("Negative sales:\n", negative_sales)

print("\n ************** Erorr value in file data  **************** \n")

search_column = 'Weekly_Sales'
zero_rows = data.loc[data[search_column] == 0]
negative_rows = data.loc[data[search_column] < 0]

print("\nZero_Row:\n")

display(zero_rows)

print("\n negative_Row:\n")

display(negative_rows)




print("\n ************** Replace Erorr value in file data  **************** \n")

data.loc[data.Weekly_Sales < 0, "Weekly_Sales"]=0




print("\n ************** handling missing value in file data   **************** \n")

data.drop(data[data['Weekly_Sales'] == 0].index , inplace=True)

print("------------------------------------------------------------------------------------------------")

#weather
missing_data = weather.isnull().sum()
#negative_sales = weather[weather['Temperature'] <= 0]
print("Missing data:\n", missing_data)
#print("Negative sales:\n", negative_sales)

print("\n ************** Erorr value in file weather  **************** \n")

search_column = 'Temperature'
zero_rows = weather.loc[weather[search_column] == 0]
negative_rows = weather.loc[weather[search_column] < 0]


print ("\nZero_Row:\n")

display(zero_rows)

print ("\n negative_Row:\n")

display(negative_rows)




#print("\n ************** Replace Erorr value in file weather  **************** \n")

weather.loc[weather.Temperature < 0, "Temperature"]=0




#print("\n ************** handling missing value in file weather  **************** \n")

weather.drop(weather[weather['Temperature'] == 0].index , inplace=True)
print('$$')

print("------------------------------------------------------------------------------------------------")


#fuel pricing
missing_data = fuel.isnull().sum()
#negative_sales = fuel[fuel['Fuel_Price'] <= 0]
print("Missing data:\n", missing_data)
#print("Negative sales:\n" , negative_sales)

print("\n ************** Erorr value in file fuel  **************** \n")

search_column = 'Fuel_Price'
zero_rows = fuel.loc[fuel[search_column] == 0]
negative_rows = fuel.loc[fuel[search_column] < 0]


print("\nZero_Row:\n")

display(zero_rows)

print("\n negative_Row:\n")

display(negative_rows)



#print("\n ************** Replace Erorr value in file fuel  **************** \n")

fuel.loc[fuel.Fuel_Price < 0, "Fuel_Price"]=0




#print("\n ************** handling missing value in file fuel  **************** \n")

fuel.drop(fuel[fuel['Fuel_Price'] == 0].index , inplace=True)


avg = weather.groupby('Store').mean()
display(avg)
data.dtypes
weather.dtypes
fuel.dtypes
display(data.loc[:9]) 
#Data1.head(10)
display(weather.loc[:9]) 
#Data2.head(10)
display(fuel.loc[:9]) 
#Data3.head(10)
data['Date']=pd.to_datetime(data['Date'])
data.dtypes
weather['Date']=pd.to_datetime(weather['Date'])
weather.dtypes
fuel['Date']=pd.to_datetime(fuel['Date'])
fuel.dtypes
display(data.select_dtypes(['int','float']).agg (['count','mean','std','min','max']))
display(weather.select_dtypes(['int','float']).agg (['count','mean','std','min','max']))
display(fuel.select_dtypes(['int','float']).agg (['count','mean','std','min','max']))
'''
 هذه الدوال الخمسة هي:

1. count: تحسب عدد القيم الغير مفقودة في كل عمود من الأعمدة التي تحددها بدلالة النوع int أو float. ويمثل هذا العدد عدد الصفوف التي يحتويها العمود.
calculates the number of non-missing values in each column of the specified data types (int or float). This number represents the number of rows that the column contains.

2. mean: تحسب المتوسط الحسابي للأعداد في كل عمود.
 calculates the arithmetic mean of the numbers in each column.

3. std: تحسب الانحراف المعياري للأعداد في كل عمود. يعطي فكرة عن انتشار القيم في العمود.
calculates the standard deviation of the numbers in each column. It gives an idea of the spread of values in the column.

4. min: تحسب القيمة الصغرى في كل عمود.
calculates the minimum value in each column
5. max: تحسب القيمة الكبرى في كل عمود.
calculates the maximum value in each column.


'''
merged = pd.merge(data, weather, on=['Store', 'Date'] )
merged = pd.merge(merged,fuel, on=['Store', 'Date'])
display(merged)
# Out:
#         Store  Category        Date  Weekly_Sales  Holiday
# 0           1         1  2010-02-05      24924.50    False
# 1           1         1  2010-02-12      46039.49     True
# 2           1         1  2010-02-19      41595.55    False
# 3           1         1  2010-02-26      19403.54    False
# 4           1         1  2010-03-05      21827.90    False
# ...       ...       ...         ...           ...      ...
# 421565     45        98  2012-09-28        508.37    False
# 421566     45        98  2012-10-05        628.10    False
# 421567     45        98  2012-10-12       1061.02    False
# 421568     45        98  2012-10-19        760.01    False
# 421569     45        98  2012-10-26       1076.80    False
#
# [421570 rows x 5 columns]
#       Store        Date  Temperature
# 0         1  2010-02-05        42.31
# 1         1  2010-02-12        38.51
# 2         1  2010-02-19        39.93
# 3         1  2010-02-26        46.63
# 4         1  2010-03-05        46.50
# ...

# %% [markdown]
# ## **Visualization**

# %%
#1
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('data.csv')
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values('Date')
sns.lineplot(data=df, x='Date', y='Weekly_Sales')
plt.style.use('bmh')
plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.title('The Weekly Sales over Time')
plt.tight_layout()
plt.show()

# %%
#2
sns.barplot(data=df, x='Store', y='Weekly_Sales')
plt.tight_layout()
plt.show()

# %%
#3
store_sales = df.groupby('Store')['Weekly_Sales'].sum()
top_10_stores = store_sales.sort_values(ascending=False)[:10]

sns.barplot(x=top_10_stores.index, y=top_10_stores.values)
plt.title('Top 10 Selling Stores')
plt.xlabel('Store')
plt.ylabel('Total Weekly Sales')
plt.tight_layout()
plt.show()

# %%
#3
top_10stores = store_sales.sort_values(ascending=False)[:10]
plt.bar(top_10stores.index, top_10stores.values)
plt.title('Top Ten Selling Stores')
plt.xlabel('Store')
plt.ylabel('Weekly Sales')
plt.tight_layout()
plt.show()

# %%
#4
store_sales = df.groupby('Store')['Weekly_Sales'].sum()
top_10_stores = store_sales.sort_values(ascending=False)[:10]


df_top_10 = df[df['Store'].isin(top_10_stores.index)]

sns.histplot(data=df_top_10, x='Store', weights='Weekly_Sales', bins=40)
plt.title('Top 10 Selling Stores')
plt.xlabel('Store')
plt.ylabel('Total Weekly Sales')
plt.tight_layout()
plt.show()

# %%
#5

store_sales = df.groupby('Store')['Weekly_Sales'].sum()  
top_10_stores = store_sales.sort_values(ascending=False).head(10)
display(top_10_stores)
average_sales =df.groupby(['Store', 'Holiday'])['Weekly_Sales'].mean().reset_index()
top_10_stores = store_sales.nlargest(10).index
top_10_sales = average_sales[average_sales['Store'].isin(top_10_stores)]
sns.barplot(data=top_10_sales, x='Store', y='Weekly_Sales', hue='Holiday')
plt.title(' The Average Sales for the Top 10 Stores during Holidays and Non-Holidays')
# Out:
# Store
# 20    3.013978e+08
# 4     2.995440e+08
# 14    2.889999e+08
# 13    2.865177e+08
# 2     2.753824e+08
# 10    2.716177e+08
# 27    2.538559e+08
# 6     2.237561e+08
# 1     2.224028e+08
# 39    2.074455e+08
# Name: Weekly_Sales, dtype: float64
# Text(0.5, 1.0, ' The Average Sales for the Top 10 Stores during Holidays and Non-Holidays')

# %%
#6
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data = pd.read_csv('data.csv')

store_sales = data.groupby('Store')['Weekly_Sales'].sum()

top_10_stores = store_sales.nlargest(10)

average_sales_by_store = data[data['Store'].isin(top_10_stores.index)].groupby('Store')['Weekly_Sales'].mean()

plt.figure(figsize=(10, 6))
sns.barplot(x=average_sales_by_store.index, y=average_sales_by_store.values)
plt.xlabel('Store')
plt.ylabel('Average Sales')
plt.title('Average Sales by Store for Top 10 Stores')

plt.show()

# %%
#6
df = pd.read_csv('data.csv')
top_stores = df.groupby('Store')['Weekly_Sales'].sum().sort_values(ascending=False).head(10)
filtered_data = df[df['Store'].isin(top_stores.index)]
grouped_data = filtered_data.groupby(['Category','Store'])['Weekly_Sales'].mean( ).unstack()
grouped_data.plot(kind='bar', figsize=(10,6)) 
plt.title('Average Weekly Sales by Brand Department for Top 10 Selling Stores')
plt.xlabel('Brand Department') 
plt.ylabel('Average Weekly Sales ($)') 
plt.legend(title='Store', loc='upper right') 
plt.tight_layout()
plt.show() '''
# Out:
# "df = pd.read_csv('data.csv')\ntop_stores = df.groupby('Store')['Weekly_Sales'].sum().sort_values(ascending=False).head(10)\nfiltered_data = df[df['Store'].isin(top_stores.index)]\ngrouped_data = filtered_data.groupby(['Category','Store'])['Weekly_Sales'].mean( ).unstack()\ngrouped_data.plot(kind='bar', figsize=(10,6)) \nplt.title('Average Weekly Sales by Brand Department for Top 10 Selling Stores')\nplt.xlabel('Brand Department') \nplt.ylabel('Average Weekly Sales ($)') \nplt.legend(title='Store', loc='upper right') \nplt.show() "

# %%
#7
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.read_csv('data.csv')
dff = pd.read_csv('weather.csv')

#num_rows = 100
#column_name = 'Weekly_Sales'
#first_100_sales = df[column_name][:num_rows]

data = pd.merge(df[['Weekly_Sales']], dff[['Temperature']], left_index=True, right_index=True)
#sns.lineplot(x= 'Temperature',y=first_100_sales, data=data)
sns.lineplot(x= 'Temperature',y='Weekly_Sales', data=data)
plt.title("Relation between Weekly Sales and Temperature")
plt.style.use('seaborn')
plt.show()
# Out:
# <ipython-input-7-a89b39eca52b>:17: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
#8
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.read_csv('data.csv')
dff = pd.read_csv('fuel pricing.csv')

#num_rows = 100
#column_name = 'Weekly_Sales'
#first_100_sales = df[column_name][:num_rows] 

data = pd.merge(df[['Weekly_Sales']], dff[['Fuel_Price']], left_index=True, right_index=True)


#sns.lineplot(x= 'Fuel_Price',y=first_100_sales, data=data)
sns.lineplot(x= 'Fuel_Price',y='Weekly_Sales', data=data)

plt.title("Relation between Weekly Sales and Fuel_Price")
plt.style.use('seaborn')
plt.show()
# Out:
# <ipython-input-6-ffcbdcfad5e1>:20: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# # **Modeling**

# %%
import numpy as np 
import pandas as pd 
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import accuracy_score

# %%
data1 = pd.read_csv('data.csv')
display(data1.head(10))
print("Data1 shape is ", data1.shape)
na1 = data1.isna().sum()
print(na1)
print("----------------------------------------------------------------------------------------------------")
data2 = pd.read_csv('fuel pricing.csv')
display(data2.head(10))
print("Data2 shape is ", data2.shape)
na2 = data2.isna().sum()
print(na2)
print("----------------------------------------------------------------------------------------------------")
data3 = pd.read_csv('weather.csv')
display(data3.head(10))
print("Data3 shape is ", data3.shape)
na3 = data3.isna().sum()
print(na3)
# Out:
#    Store  Category        Date  Weekly_Sales  Holiday
# 0      1         1  2010-02-05      24924.50    False
# 1      1         1  2010-02-12      46039.49     True
# 2      1         1  2010-02-19      41595.55    False
# 3      1         1  2010-02-26      19403.54    False
# 4      1         1  2010-03-05      21827.90    False
# 5      1         1  2010-03-12      21043.39    False
# 6      1         1  2010-03-19      22136.64    False
# 7      1         1  2010-03-26      26229.21    False
# 8      1         1  2010-04-02      57258.43    False
# 9      1         1  2010-04-09      42960.91    False
# Data1 shape is  (421570, 5)
# Store           0
# Category        0
# Date            0
# Weekly_Sales    0
# Holiday         0
# dtype: int64
# ----------------------------------------------------------------------------------------------------
#    Store        Date  Fuel_Price
# 0      1  2010-02-05       2.572
# 1      1  2010-02-12       2.548
# ...

# %%
data1.drop(['Date'], axis = 1, inplace = True)
#x = data1.drop(columns = ['Weekly_Sales']) #x = data1['Weekly_Sales']
x = data1
y = data1['Weekly_Sales']
display(x)
display(y)
# Out:
#         Store  Category  Weekly_Sales  Holiday
# 0           1         1      24924.50    False
# 1           1         1      46039.49     True
# 2           1         1      41595.55    False
# 3           1         1      19403.54    False
# 4           1         1      21827.90    False
# ...       ...       ...           ...      ...
# 421565     45        98        508.37    False
# 421566     45        98        628.10    False
# 421567     45        98       1061.02    False
# 421568     45        98        760.01    False
# 421569     45        98       1076.80    False
#
# [421570 rows x 4 columns]
# 0         24924.50
# 1         46039.49
# 2         41595.55
# 3         19403.54
# 4         21827.90
#             ...
# 421565      508.37
# 421566      628.10
# 421567     1061.02
# 421568      760.01
# 421569     1076.80
# Name: Weekly_Sales, Length: 421570, dtype: float64

# %%
#x = np.array(x).reshape(-1,1)
y = np.array(y).reshape(-1,1)
scaler = MinMaxScaler(feature_range = (10, 100))
y = scaler.fit_transform(y)
display(y)
# Out:
# array([[13.85654594],
#        [16.57876475],
#        [16.00583637],
#        ...,
#        [10.77998213],
#        [10.74117486],
#        [10.78201654]])

# %%
lb = preprocessing.LabelEncoder()
x.Holiday = lb.fit_transform(x.Holiday)
display(x)
# Out:
#         Store  Category  Weekly_Sales  Holiday
# 0           1         1      24924.50        0
# 1           1         1      46039.49        1
# 2           1         1      41595.55        0
# 3           1         1      19403.54        0
# 4           1         1      21827.90        0
# ...       ...       ...           ...      ...
# 421565     45        98        508.37        0
# 421566     45        98        628.10        0
# 421567     45        98       1061.02        0
# 421568     45        98        760.01        0
# 421569     45        98       1076.80        0
#
# [421570 rows x 4 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.2)

# %%
# Decision Tree Regressor
model1 = DecisionTreeRegressor()
model1.fit(x_train, y_train)
DTR_Accuracy = model1.score(x_test, y_test)
print("Accuracy = ", DTR_Accuracy)
# Out:
# Accuracy =  0.9999959943703948

# %%
# Gradient Boosting Regressor
model2 = GradientBoostingRegressor()
model2.fit(x_train, y_train)
GBR_Accuracy = model2.score(x_test, y_test)
print("Accuracy = ", GBR_Accuracy)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Accuracy =  0.9998968050788266

# %%
if DTR_Accuracy > GBR_Accuracy :
     print("DTR_Accuracy is more accurate than GBR_Accuracy : {:.2f}%".format(DTR_Accuracy*100.00))
elif GBR_Accuracy > DTR_Accuracy :
    print("GBR_Accuracy is more accurate than DTR_Accuracy : {:.2f}%".format(GBR_Accuracy*100.00))
else:
    print("Both models have the same accuracy")
# Out:
# DTR_Accuracy is more accurate than GBR_Accuracy : 100.00%
